# %% [markdown]
# **1. Membuat Node**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

n1 = Node('January')
n2 = Node('February')
n3 = Node('March')

print (n1.dataval)
print (n2.dataval)
print (n3.dataval)
# Out:
# January
# February
# March

# %% [markdown]
# **2. Membuat Class Linked-List**

# %%
class LinkedList:
  def __init__(self):
    self.headval = None

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

# %% [markdown]
# **3. Menelusuri Linked-List**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class LinkedList:
  def __init__(self):
    self.headval = None

  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.listprint()
# Out:
# January
# February
# March

# %% [markdown]
# **4. Penyisipan di Awal**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

# create node
n1 = Node("Blablabla")
n2 = Node("Blebleble")
n3 = Node("Blobloblo")

class LinkedList:
  def __init__(self):
    self.headval = None

# print the linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

# create attribute add beginning to Update the new nodes next value to existing node
  def AddBeginning(self,newdata):
    NewNode = Node(newdata)
    NewNode.nextval = self.headval
    self.headval = NewNode

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.AddBeginning("Start")
Li.listprint()
# Out:
# Start
# Blablabla
# Blebleble
# Blobloblo

# %% [markdown]
# **5. Penyisipan di Tengah**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None
# create node
n1 = Node("Chris")
n2 = Node("Claire")

class Redfield:
  def __init__(self):
    self.headval = None

# print the linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

# function to add node in the middle
  def AddInBetween(self,mid_node,newdata):
    if mid_node is None:
      print("The mentioned node is absent")
      return
    NewNode = Node(newdata)
    NewNode.nextval = mid_node.nextval
    mid_node.nextval = NewNode

R = Redfield()
R.headval = n1

# link first Node to second node
R.headval.nextval = n2

# add node after n1
R.AddInBetween(n1,"Leon")
R.listprint()
# Out:
# Chris
# Leon
# Claire

# %% [markdown]
# **6. Penyisipan di Akhir**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None
# create node
n1 = Node("Ethan")
n2 = Node("Mia")

class Winters:
  def __init__(self):
    self.headval = None

# print the linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

# function to add newnode in the end
  def AddInEnd(self,newdata):
    NewNode = Node(newdata)
    if self.headval is None:
       self.headval = NewNode
       return
    last = self.headval
    while(last.nextval):
      last = last.nextval
    last.nextval=NewNode

W = Winters()
W.headval = n1

# link first Node to second node
W.headval.nextval = n2

# add node in the end
W.AddInEnd("Rose")
W.listprint()
# Out:
# Ethan
# Mia
# Rose

# %% [markdown]
# **7. Menghapus Node**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class LinkedList:
  def __init__(self):
    self.headval = None

# Print the linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

# Function to add node in the beginning
  def AddBeginning(self,newdata):
    NewNode = Node(newdata)
# Update the new nodes next val to existing node
    NewNode.nextval = self.headval
    self.headval = NewNode

# Function to remove node by key
  def RemoveNode(self, Removekey):
    HeadVal = self.headval

    if (HeadVal is not None):
      if (HeadVal.dataval == Removekey):
        self.headval = HeadVal.nextval
        HeadVal = None
        return
    while (HeadVal is not None):
      if HeadVal.dataval == Removekey:
        break
      prev = HeadVal
      HeadVal = HeadVal.nextval
    if (HeadVal == None):
      return
    prev.nextval = HeadVal.nextval
    HeadVal = None

# Create Linked list named Li
Li = LinkedList()

# add node
Li.AddBeginning("Mpruy")
Li.AddBeginning("Resbob")
Li.AddBeginning("Sape")
Li.AddBeginning("Lau")
print("Before removed")
Li.listprint()
print("=================================================================")

# remove node by key = "Resbob"
Li.RemoveNode("Resbob")
print("After removed")
Li.listprint()
# Out:
# Before removed
# Lau
# Sape
# Resbob
# Mpruy
# =================================================================
# After removed
# Lau
# Sape
# Mpruy

# %% [markdown]
# **8. Menghapus Node di Awal**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class LinkedList:
  def __init__(self):
    self.headval = None

# Print the linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

# Function to add node in the beginning
  def AddBeginning(self,newdata):
    NewNode = Node(newdata)
# Update the new nodes next val to existing node
    NewNode.nextval = self.headval
    self.headval = NewNode

# Function to remove first node
  def RemoveFirst(self):
    afterhead = self.headval
    self.headval = afterhead.nextval

# Create Linked list named Li
Li = LinkedList()

# add node
Li.AddBeginning("Mpruy")
Li.AddBeginning("Sape")
Li.AddBeginning("Lau")
Li.AddBeginning("Resbob")
print("Before removed")
Li.listprint()
print("=================================================================")

# remove first node
Li.RemoveFirst()
print("After removed")
Li.listprint()
# Out:
# Before removed
# Resbob
# Lau
# Sape
# Mpruy
# =================================================================
# After removed
# Lau
# Sape
# Mpruy

# %% [markdown]
# **9. Menghapus Node di Akhir**

# %%
class Node:
  def __init__(self, dataval=None):
    self.dataval = dataval
    self.nextval = None

class LinkedList:
  def __init__(self):
    self.headval = None

# Print the linked list
  def listprint(self):
    printval = self.headval
    while printval is not None:
      print (printval.dataval)
      printval = printval.nextval

# Function to add node in the end
  def AddInEnd(self,newdata):
    NewNode = Node(newdata)
    if self.headval is None:
       self.headval = NewNode
       return
    last = self.headval
    while(last.nextval):
      last = last.nextval
    last.nextval=NewNode

# Function to remove last node
  def RemoveEnd(self):
    last = self.headval
    while (last is not None):
      if last.nextval == None:
        break
      prev = last
      last = last.nextval
    if (last == None):
      return
    prev.nextval = last.nextval
    last = None

# Create Linked list named Li
Li = LinkedList()

# add node
Li.AddInEnd("Lau")
Li.AddInEnd("Sape")
Li.AddInEnd("Mpruy")
Li.AddInEnd("Resbob")
print("Before removed")
Li.listprint()
print("=================================================================")

# remove last node
Li.RemoveEnd()
print("After removed")
Li.listprint()
# Out:
# Before removed
# Lau
# Sape
# Mpruy
# Resbob
# =================================================================
# After removed
# Lau
# Sape
# Mpruy
